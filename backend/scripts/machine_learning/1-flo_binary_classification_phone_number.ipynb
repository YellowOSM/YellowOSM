# %%
DIM = 50
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
import random
import json
import numpy as np
import pandas as pd

# %%
data = []
with open("training_data_1.json", 'r') as myfile:
    data = json.loads(myfile.read())
len(data)
# Out:
# 1255

# %%
not_phones = []
phones = []

for el in data:
    phones.append([el[0]['phone_web'], 1])
    for not_phone in el[1]:
        not_phones.append([not_phone, 0])


training_data = np.zeros((len(phones)*2, 51))
        
pvs = []
for p,i in zip(phones, range(0,len(phones))):
    pv = []
    for c,j in zip(p[0], range(0,len(p[0]))):
        training_data[i,j] = ord(c)
    pvs.append(pv + [int(p[1])])

random.shuffle(not_phones)
npvs = []
for noph,i in zip(not_phones[:len(phones)], range(len(phones),(len(phones)*2))):
    npv = []
    for c,j in zip(noph[0], range(0,len(noph[0]))):
        training_data[i,j] = ord(c)
    npvs.append(npv + [int(noph[1])])


np.random.shuffle(training_data)
# training_data = pvs + npvs
# random.shuffle(training_data)
# # print("len phones: "+ str(len(phones))+ " " + str(len(training_data)))

# %%
print(len(training_data), len(phones))
# Out:
# 2510 1255

# %%
training_data = training_data.astype(int)

# %%
my_training_data = np.array(training_data)
x_train = my_training_data[:int(len(training_data)*0.9), :DIM]
y_train = my_training_data[:int(len(training_data)*0.9), DIM:]
x_test = my_training_data[int(len(training_data)*0.9):, :DIM]
y_test = my_training_data[int(len(training_data)*0.9):, DIM:]

# %%
my_training_data.shape
# Out:
# (2510, 51)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (2259, 50)
# (2259, 1)
# (251, 50)
# (251, 1)

# %%
# from keras.utils import to_categorical
from keras.utils.np_utils import to_categorical
y_train_cat = to_categorical(y_train, num_classes=2, dtype='int32')
y_train_cat
y_test_cat = to_categorical(y_test, num_classes=2, dtype='int32')

# %%
model = Sequential()
model.add(Dense(units=DIM, activation='relu', input_dim=DIM))
model.add(Dense(units=20, activation='relu'))
model.add(Dense(units=2, activation='softmax'))
model.compile(loss='categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy'])
model.fit(x_train, y_train_cat, epochs=5, batch_size=320)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/5
# 2259/2259 [==============================] - 0s 180us/step - loss: 0.0318 - acc: 0.9951
# Epoch 2/5
# 2259/2259 [==============================] - 0s 9us/step - loss: 0.0146 - acc: 0.9991
# Epoch 3/5
# 2259/2259 [==============================] - 0s 23us/step - loss: 0.0145 - acc: 0.9991
# Epoch 4/5
# 2259/2259 [==============================] - 0s 15us/step - loss: 0.0144 - acc: 0.9991
# Epoch 5/5
# 2259/2259 [==============================] - 0s 16us/step - loss: 0.0144 - acc: 0.9991

# %%
loss_and_metrics = model.evaluate(x_test, y_test_cat, batch_size=128)
# Out:
# 251/251 [==============================] - 0s 209us/step

# %%
loss_and_metrics
# Out:
# [6.764049714141752e-05, 1.0]

# %%
classes = model.predict(x_test, batch_size=128)

# %%
classes
# Out:
# array([[  1.00000000e+00,   3.15778821e-30],
#        [  9.99999881e-01,   1.31971831e-07],
#        [  1.00000000e+00,   6.77027134e-36],
#        [  9.94786263e-01,   5.21369139e-03],
#        [  9.99999642e-01,   3.43995794e-07],
#        [  1.00000000e+00,   5.22351086e-11],
#        [  1.00000000e+00,   8.56366089e-11],
#        [  1.00000000e+00,   3.03604364e-12],
#        [  1.00000000e+00,   1.10333653e-08],
#        [  1.00000000e+00,   1.72644607e-10],
#        [  1.00000000e+00,   4.09468637e-09],
#        [  1.00000000e+00,   1.77994366e-08],
#        [  1.00000000e+00,   3.09637455e-11],
#        [  1.00000000e+00,   4.58446010e-08],
#        [  1.00000000e+00,   0.00000000e+00],
#        [  1.00000000e+00,

#        [  1.00000000e+00,   0.00000000e+00],
#        [  1.00000000e+00,   1.66167769e-30],
#        [  1.00000000e+00,   5.82548732e-20],
#        [  1.00000000e+00,   4.58446010e-08],
#        [  1.00000000e+00,   2.02320135e-23],
#        [  1.00000000e+00,   1.98629517e-16],
#        [  1.00000000e+00,   1.89291138e-09],
#        [  1.00000000e+00,   0.00000000e+00],
#        [  1.00000000e+00,   2.89820035e-09],
#        [  1.00000000e+00,   5.37313988e-21],
#        [  1.00000000e+00,   1.02249640e-08],
#        [  1.00000000e+00,   9.68513117e-11],
#        [  1.00000000e+00,   9.26440384e-18],
#        [  1.00000000e+00,   1.96370138e-08],
#        [  1.00000000e+00,   1.47954093e-10],
#        [  1.00000000e+00,   4.30601997e-23],
#        [  1.00000000e+00,   2.56902106e-27],
#        [  1.00000000e+00,   9.54099690e-19],
#        [  1.00000000e+00,   4.31506209e-09],
#        [  1.00000000e+00,   1.25246185e-11],
#        [  1.00000000e+00,   2.07069605e-14],
#        [  9.99999404e-01,   6.07645859e-07],
#        [  1.00000000e+00,   1.13074217e-17],
#        [  1.00000000e+00,   6.97525631e-12],
#        [  1.00000000e+00,   2.23020002e-08],
#        [  1.00000000e+00,   2.02893264e-34],
#        [  9.99999881e-01,   6.71087932e-08],
#        [  1.00000000e+00,   0.00000000e+00],
#        [  1.00000000e+00,   2.51396516e-12],
#        [  9.99999642e-01,   3.04496382e-07],
#        [  1.00000000e+00,   4.58446010e-08],
#        [  1.00000000e+00,   5.79728798e-09],
#        [  9.99999404e-01,   6.17122510e-07],
#        [  1.00000000e+00,   3.90781101e-35],
#        [  1.00000000e+00,   1.24584371e-10],
#        [  1.00000000e+00,   6.42833267e-20],
#        [  1.00000000e+00,   0.00000000e+00],
#        [  1.00000000e+00,   4.60584566e-08],
#        [  1.00000000e+00,   8.50249814e-26],
#        [  9.99998927e-01,   1.09235373e-06],
#        [  1.00000000e+00,   0.00000000e+00],
#        [  1.00000000e+00,   3.37011896e-20],
#        [  1.00000000e+00,   1.21343014e-22],
#        [  1.00000000e+00,   2.56174415e-09],
#        [  1.00000000e+00,   2.18472529e-08],
#        [  1.00000000e+00,   2.40586715e-08],
#        [  1.00000000e+00,   1.02492916e-12],
#        [  1.00000000e+00,   5.65131652e-21],
#        [  1.00000000e+00,   2.89758391e-11],
#        [  1.00000000e+00,   9.40745082e-09],
#        [  9.99999404e-01,   6.28282464e-07],
#        [  1.00000000e+00,   1.39176431e-11],
#        [  1.00000000e+00,   0.00000000e+00],
#        [  1.00000000e+00,   2.88551547e-08],
#        [  1.00000000e+00,   9.95561189e-10],
#        [  1.00000000e+00,   1.26738067e-14],
#        [  1.00000000e+00,   6.46652107e-11],
#        [  1.00000000e+00,   1.02721653e-09],
#        [  1.00000000e+00,   3.20402677e-10],
#        [  1.00000000e+00,   2.97646726e-21],
#        [  1.00000000e+00,   8.02514588e-09],
#        [  1.00000000e+00,   0.00000000e+00],
#        [  1.00000000e+00,   2.94765644e-12],
#        [  1.00000000e+00,   1.29809996e-09],
#        [  1.00000000e+00,   1.59846734e-12],
#        [  1.00000000e+00,   1.74330424e-15],
#        [  1.00000000e+00,   4.93451914e-17],
#        [  1.00000000e+00,   1.18725494e-12],
#        [  1.00000000e+00,   4.65963748e-13],
#        [  1.00000000e+00,   1.26423415e-15]], dtype=float32)

# %%
model.metrics_names
# Out:
# ['loss', 'acc']
